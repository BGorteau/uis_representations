# %% [markdown]
# # Data visualization fir UIS data

# %%
import pandas as pd
import datapackage
from datapackage import Package
import geopandas as gpd
import geoplot
import geoplot.crs as gcrs
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.colors import ListedColormap
import country_converter as coco
from mpl_toolkits.axes_grid1 import make_axes_locatable
import numpy as np
import matplotlib as mpl
from sklearn.linear_model import LinearRegression
from matplotlib.lines import Line2D
from adjustText import adjust_text
from matplotlib.patheffects import withStroke
from matplotlib import lines
from matplotlib import patches
from matplotlib.font_manager import FontProperties
from matplotlib import font_manager

# %%
# !rm -fr ~/.cache/matplotlib

# %%
font_manager.findSystemFonts(fontpaths=None, fontext="ttf")
# Out:
# ['/System/Library/Fonts/Supplemental/NotoSansKhojki-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/STIXNonUni.otf',
#  '/System/Library/Fonts/MarkerFelt.ttc',
#  '/System/Library/Fonts/Supplemental/Andale Mono.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansHanifiRohingya-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansNabataean-Regular.ttf',
#  '/System/Library/Fonts/NotoSansArmenian.ttc',
#  '/System/Library/Fonts/Supplemental/AmericanTypewriter.ttc',
#  '/System/Library/Fonts/Supplemental/STIXSizThreeSymBol.otf',
#  '/System/Library/Fonts/Apple Braille Pinpoint 8 Dot.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansBassaVah-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/Wingdings 2.ttf',
#  '/System/Library/Fonts/Supplemental/NotoSansHanunoo-Regular.ttf',
#  '/System/Library/Fonts/Supplemental/PTSerif.ttc',
#  '/System/Library/Fonts/Supplemental/NotoSansGunjalaGondi-Regular.otf',
#  '/System/Library/Fonts/KohinoorGujarati.ttc',
# ...

# %%
font_manager.findfont("Geneva")
# Out:
# '/System/Library/Fonts/Geneva.ttf'

# %%
# Chemin vers le fichier .ttf de la police
font_path = 'data/econsanscnd.woff.ttf'

# Charger la police
custom_font = FontProperties(fname=font_path)
custom_font_bold = FontProperties(fname=font_path, weight=800)

# %%
data_scolarisation = pd.read_csv("data/data_scolarisation.csv")
# Keep datas for 2021 and one indicator
data_scolarisation = data_scolarisation[(data_scolarisation["TIME"]==2021)&(data_scolarisation["NATMON_IND"]=="NERT_3_CP")][["LOCATION", "Value"]]
# Set the indices of the dataframe
data_scolarisation.index = range(len(data_scolarisation))
# Rename the "LOCATION" column
data_scolarisation["id"] = data_scolarisation["LOCATION"]
# Drop "LOCATION" column
data_scolarisation = data_scolarisation.drop(columns=["LOCATION"])

# %%
data_scolarisation
# Out:
#         Value   id
# 0    55.55752  KHM
# 1    96.01202  ARG
# 2    26.71737  GIN
# 3    78.80282  ECU
# 4    93.51477  AUT
# ..        ...  ...
# 124  77.18457  BIH
# 125  50.67626  PAK
# 126  51.41057  GMB
# 127  67.28777  FSM
# 128  84.05439  AND
#
# [129 rows x 2 columns]

# %% [markdown]
# ## Completion rate

# %%
completion_rate_data = pd.read_csv("data/global_completion.csv")

# %%
completion_rate_data
# Out:
#                               Region      Country  Target Indicator Number  \
# 0     SDG: Central and Southern Asia  Afghanistan     4.1            4.1.2
# 1     SDG: Central and Southern Asia  Afghanistan     4.1            4.1.2
# 2     SDG: Central and Southern Asia  Afghanistan     4.1            4.1.2
# 3     SDG: Central and Southern Asia  Afghanistan     4.1            4.1.2
# 4     SDG: Central and Southern Asia  Afghanistan     4.1            4.1.2
# ...                              ...          ...     ...              ...
# 1280         SDG: Sub-Saharan Africa     Zimbabwe     4.1            4.1.2
# 1281         SDG: Sub-Saharan Africa     Zimbabwe     4.1            4.1.2
# 1282         SDG: Sub-Saharan Africa     Zimbabwe     4.1            4.1.2
# 1283         SDG: Sub-Saharan Africa     Zimbabwe     4.1            4.1.2
# 1284         SDG: Sub-Saharan Africa     Zimbabwe     4.1            4.1.2
#
# ...

# %%
indicators = list(pd.unique(completion_rate_data["Indicator Name"]))

# %%
print(indicators)
# Out:
# ['Completion rate, primary education, both sexes (%)', 'Completion rate, lower secondary education, both sexes (%)', 'Completion rate, upper secondary education, both sexes (%)']

# %% [markdown]
# ### Primary education

# %%
completion_pe = completion_rate_data[completion_rate_data["Indicator Name"]==indicators[0]]

new_completion_pe = pd.DataFrame()
for country in pd.unique(completion_pe["Country"]) :
    last_year = max(list(completion_pe[completion_pe["Country"]==country]["Year"]))
    new_completion_pe = pd.concat([new_completion_pe, completion_pe[(completion_pe["Country"]==country)&(completion_pe["Year"]==last_year)]])
    
new_completion_pe["id"] = coco.convert(names=list(new_completion_pe["Country"]), to='ISO3')

# %% [markdown]
# ### Lower secondary

# %%
completion_lse = completion_rate_data[completion_rate_data["Indicator Name"]==indicators[1]]

new_completion_lse = pd.DataFrame()
for country in pd.unique(completion_lse["Country"]) :
    last_year = max(list(completion_lse[completion_lse["Country"]==country]["Year"]))
    new_completion_lse = pd.concat([new_completion_lse, completion_lse[(completion_lse["Country"]==country)&(completion_lse["Year"]==last_year)]])
    
new_completion_lse["id"] = coco.convert(names=list(new_completion_lse["Country"]), to='ISO3')

# %% [markdown]
# ### Upper secondary

# %%
completion_use = completion_rate_data[completion_rate_data["Indicator Name"]==indicators[2]]

new_completion_use = pd.DataFrame()
for country in pd.unique(completion_use["Country"]) :
    last_year = max(list(completion_use[completion_use["Country"]==country]["Year"]))
    new_completion_use = pd.concat([new_completion_use, completion_use[(completion_use["Country"]==country)&(completion_use["Year"]==last_year)]])
    
new_completion_use["id"] = coco.convert(names=list(new_completion_use["Country"]), to='ISO3')

# %% [markdown]
# # Import geospatial datas

# %% [markdown]
# ## Primary education

# %%
world_data_pe = gpd.read_file(geoplot.datasets.get_path('world'))
# Merge the world data with the UIS datas
world_data_pe = pd.merge(world_data_pe, new_completion_pe, on="id", how="outer")
# Keep useful datas
world_data_pe = world_data_pe[world_data_pe["geometry"]!=None]
# Repalce NA values by 0 in the "Value" column
world_data_pe["Value"] = world_data_pe["Value"].fillna(0)
# Remove Antarctica
world_data_pe = world_data_pe[world_data_pe["name"]!="Antarctica"]

# %% [markdown]
# ## Lower secondary education

# %%
world_data_lse = gpd.read_file(geoplot.datasets.get_path('world'))
# Merge the world data with the UIS datas
world_data_lse = pd.merge(world_data_lse, new_completion_lse, on="id", how="outer")
# Keep useful datas
world_data_lse = world_data_lse[world_data_lse["geometry"]!=None]
# Repalce NA values by 0 in the "Value" column
world_data_lse["Value"] = world_data_lse["Value"].fillna(0)
# Remove Antarctica
world_data_lse = world_data_lse[world_data_lse["name"]!="Antarctica"]

# %% [markdown]
# ## Upper secondary data

# %%
world_data_use = gpd.read_file(geoplot.datasets.get_path('world'))
# Merge the world data with the UIS datas
world_data_use = pd.merge(world_data_use, new_completion_use, on="id", how="outer")
# Keep useful datas
world_data_use = world_data_use[world_data_use["geometry"]!=None]
# Repalce NA values by 0 in the "Value" column
world_data_use["Value"] = world_data_use["Value"].fillna(0)
# Remove Antarctica
world_data_use = world_data_use[world_data_use["name"]!="Antarctica"]

# %% [markdown]
# # Create the colormap

# %%
cmap = plt.cm.Blues 
cmap_list = [cmap(i) for i in range(cmap.N)]
cmap_list[0] = (0.8, 0.8, 0.8, 1.0)
custom_cmap = ListedColormap(cmap_list)

# %% [markdown]
# # Mapping the datas

# %%
fig, axs = plt.subplots(4, 1, figsize=(10, 12), gridspec_kw={'height_ratios': [1, 1, 1, 0.1]})

# Tracer la première représentation sur le premier sous-graphique
world_data_pe.plot(ax=axs[0], edgecolor="white", column='Value', cmap=custom_cmap, linewidth=0.3)
axs[0].set_title("Primary", size=15, fontfamily="Tahoma")
axs[0].axis('off')

# Tracer la deuxième représentation sur le deuxième sous-graphique
world_data_lse.plot(ax=axs[1], edgecolor="white", column='Value', cmap=custom_cmap, linewidth=0.3)
axs[1].set_title("Lower secondary", size=15, fontfamily="Tahoma")
axs[1].axis('off')

# Tracer la troisième représentation sur le deuxième sous-graphique
world_data_use.plot(ax=axs[2], edgecolor="white", column='Value', cmap=custom_cmap, linewidth=0.3)
axs[2].set_title("Upper secondary", size=15, fontfamily="Tahoma")
axs[2].axis('off')


cmap = plt.cm.Blues
norm = mpl.colors.Normalize(vmin=0, vmax=100)

cbar = plt.colorbar(mpl.cm.ScalarMappable(norm=norm, cmap=cmap),
             cax=axs[3], orientation='horizontal', label='Completion rate (%)')

cbar.ax.set_aspect(7)

cbar.ax.set_frame_on(False)
cbar.ax.xaxis.set_ticks_position('bottom')
cbar.ax.xaxis.label.set_size(12)

fig.suptitle("Completion rate for every level of education \n (SGD 4, Indicator 1.4.2)", size=20, y=1.07, fontweight="semibold", fontfamily="Tahoma")

fig.text(0.5, 0.95, "The completion rate is the percentage of a cohort of children aged \n 3–5 years above the official age at which they are supposed to \n complete a level of education.", ha='center', fontsize=13, fontfamily="Tahoma") 
fig.text(0.15, -0.045, "Last record available for each country between 2018 and 2023 \nSource: UIS Data (sdg4-data.uis.unesco.org) \nBaptiste Gorteau - bgorteau.github.io", ha='left', fontsize=12, fontfamily="Tahoma", color="#a2a2a2") 
fig.set_facecolor("white")
plt.tight_layout()
fig.savefig("figures/completion_rate.png", dpi=300, bbox_inches='tight', pad_inches=0.5)

# %% [markdown]
# # Internet acces / literacy

# %% [markdown]
# ## Internet access data

# %%
internet_acces_data = pd.read_csv("data/reading_primary.csv")

# %%
internet_acces_data
# Out:
#                                    Region                   Country  Target  \
# 0        SDG: Europe and Northern America                   Albania     4.1
# 1   SDG: Northern Africa and Western Asia      United Arab Emirates     4.1
# 2    SDG: Latin America and the Caribbean                 Argentina     4.1
# 3        SDG: Europe and Northern America                   Austria     4.1
# 4   SDG: Northern Africa and Western Asia                Azerbaijan     4.1
# ..                                    ...                       ...     ...
# 83       SDG: Europe and Northern America  United States of America     4.1
# 84         SDG: Central and Southern Asia                Uzbekistan     4.1
# 85                      SDG: Central Asia                Uzbekistan     4.1
# 86    SDG: Eastern and South-Eastern Asia                  Viet Nam     4.1
# 87                SDG: Sub-Saharan Africa                    Zambia     4.1
#
# ...

# %%
new_internet_acces_data = pd.DataFrame()
for country in pd.unique(internet_acces_data["Country"]) :
    last_year = max(list(internet_acces_data[internet_acces_data["Country"]==country]["Year"]))
    new_internet_acces_data = pd.concat([new_internet_acces_data, internet_acces_data[(internet_acces_data["Country"]==country)&(internet_acces_data["Year"]==last_year)]])
    
new_internet_acces_data["id"] = coco.convert(names=list(new_internet_acces_data["Country"]), to='ISO3')

# %%
new_internet_acces_data
# Out:
#                                    Region                   Country  Target  \
# 0        SDG: Europe and Northern America                   Albania     4.1
# 1   SDG: Northern Africa and Western Asia      United Arab Emirates     4.1
# 2    SDG: Latin America and the Caribbean                 Argentina     4.1
# 3        SDG: Europe and Northern America                   Austria     4.1
# 4   SDG: Northern Africa and Western Asia                Azerbaijan     4.1
# ..                                    ...                       ...     ...
# 83       SDG: Europe and Northern America  United States of America     4.1
# 84         SDG: Central and Southern Asia                Uzbekistan     4.1
# 85                      SDG: Central Asia                Uzbekistan     4.1
# 86    SDG: Eastern and South-Eastern Asia                  Viet Nam     4.1
# 87                SDG: Sub-Saharan Africa                    Zambia     4.1
#
# ...

# %% [markdown]
# ## Youth literacy

# %%
youth_literacy = pd.read_csv("data/gov_expenditures.csv")

# %%
youth_literacy
# Out:
#                       Region   Country Target Indicator Number  \
# 0    SDG: Sub-Saharan Africa    Angola    1.a            1.a.2
# 1    SDG: Sub-Saharan Africa    Angola    1.a            1.a.2
# 2    SDG: Sub-Saharan Africa    Angola    1.a            1.a.2
# 3    SDG: Sub-Saharan Africa    Angola    1.a            1.a.2
# 4    SDG: Sub-Saharan Africa    Angola    1.a            1.a.2
# ..                       ...       ...    ...              ...
# 756  SDG: Sub-Saharan Africa    Zambia    1.a            1.a.2
# 757  SDG: Sub-Saharan Africa    Zambia    1.a            1.a.2
# 758  SDG: Sub-Saharan Africa    Zambia    1.a            1.a.2
# 759  SDG: Sub-Saharan Africa  Zimbabwe    1.a            1.a.2
# 760  SDG: Sub-Saharan Africa  Zimbabwe    1.a            1.a.2
#
#                                         Indicator Name  Year  Value  \
# 0    Expenditure on education as a percentage of to...  2018   5.41
# 1    Expenditure on education as a percentage of to...  2021   6.92
# ...

# %%
new_youth_literacy = pd.DataFrame()
for country in pd.unique(youth_literacy["Country"]) :
    last_year = max(list(youth_literacy[youth_literacy["Country"]==country]["Year"]))
    new_youth_literacy = pd.concat([new_youth_literacy, youth_literacy[(youth_literacy["Country"]==country)&(youth_literacy["Year"]==last_year)]])
    
new_youth_literacy["id"] = coco.convert(names=list(new_youth_literacy["Country"]), to='ISO3')

# %%
new_youth_literacy
# Out:
#                                     Region               Country Target  \
# 5                  SDG: Sub-Saharan Africa                Angola    1.a
# 6     SDG: Latin America and the Caribbean              Anguilla    1.a
# 14        SDG: Europe and Northern America               Albania    1.a
# 15        SDG: Europe and Northern America               Andorra    1.a
# 20   SDG: Northern Africa and Western Asia  United Arab Emirates    1.a
# ..                                     ...                   ...    ...
# 746                           SDG: Oceania               Vanuatu    1.a
# 749                           SDG: Oceania                 Samoa    1.a
# 752                SDG: Sub-Saharan Africa          South Africa    1.a
# 758                SDG: Sub-Saharan Africa                Zambia    1.a
# 760                SDG: Sub-Saharan Africa              Zimbabwe    1.a
#
#     Indicator Number                                     Indicator Name  Year  \
# ...

# %% [markdown]
# ## Concat dataframes

# %%
internet_literacy_data = pd.merge(new_internet_acces_data, new_youth_literacy[["Value", "id"]], on="id", how="outer")

# %%
internet_literacy_data = internet_literacy_data.dropna(subset=["Value_y"])

# %%
internet_literacy_data = internet_literacy_data.dropna(subset=["Country"])

# %%
internet_literacy_data = internet_literacy_data.rename(columns={"Value_x": "Internet_Access", "Value_y": "Youth_literacy"})

# %%
internet_literacy_data
# Out:
#                                    Region               Country  Target  \
# 0        SDG: Europe and Northern America               Albania     4.1
# 1   SDG: Northern Africa and Western Asia  United Arab Emirates     4.1
# 2    SDG: Latin America and the Caribbean             Argentina     4.1
# 3        SDG: Europe and Northern America               Austria     4.1
# 4   SDG: Northern Africa and Western Asia            Azerbaijan     4.1
# ..                                    ...                   ...     ...
# 87         SDG: Central and Southern Asia            Uzbekistan     4.1
# 88                      SDG: Central Asia            Uzbekistan     4.1
# 89                      SDG: Central Asia            Uzbekistan     4.1
# 90    SDG: Eastern and South-Eastern Asia              Viet Nam     4.1
# 91                SDG: Sub-Saharan Africa                Zambia     4.1
#
#    Indicator Number                                     Indicator Name  \
# ...

# %%
len(pd.unique(internet_literacy_data["Region"]))
# Out:
# 8

# %%
pd.Categorical(internet_literacy_data["Region"]).codes
# Out:
# array([3, 5, 4, 3, 5, 7, 3, 7, 7, 3, 5, 4, 3, 7, 7, 7, 7, 4, 4, 4, 5, 3,
#        3, 4, 4, 3, 3, 3, 7, 3, 5, 7, 4, 2, 4, 3, 3, 1, 5, 3, 5, 1, 1, 0,
#        0, 7, 2, 2, 3, 3, 2, 5, 7, 4, 3, 2, 2, 7, 4, 3, 6, 4, 4, 2, 3, 3,
#        4, 5, 3, 7, 2, 4, 3, 3, 3, 3, 7, 7, 5, 4, 3, 1, 1, 0, 0, 2, 7],
#       dtype=int8)

# %% [markdown]
# ## Representation

# %%
def adjust_lightness(color, amount=0.5):
    import matplotlib.colors as mc
    import colorsys
    try:
        c = mc.cnames[color]
    except:
        c = color
    c = colorsys.rgb_to_hls(*mc.to_rgb(c))
    return colorsys.hls_to_rgb(c[0], c[1] * amount, c[2])

# %%
# Colors
# Okabe Ito colors

REGION_COLS = ["#f27cec", "#ff910a", "#8ac936", "#6cd0d9", "#069465", "#3c57cf", "#a688eb", "#cf2608"]

# Category values for the colors
CATEGORY_CODES = pd.Categorical(internet_literacy_data["Region"]).codes

# Select colors for each region according to its category.
COLORS = np.array(REGION_COLS)[CATEGORY_CODES]

# Compute colors for the edges: simply darker versions of the original colors
EDGECOLORS = [adjust_lightness(color, 0.6) for color in COLORS]

fig, ax = plt.subplots(figsize=(12, 8))
ax.scatter(internet_literacy_data["Youth_literacy"], internet_literacy_data["Internet_Access"],  color=COLORS, edgecolors=EDGECOLORS, s=80)

################# Linear Regression #################

data_linear_reg = internet_literacy_data[internet_literacy_data["Region"].isin(["SDG: Latin America and the Caribbean", "SDG: Sub-Saharan Africa", "SDG: Eastern and South-Eastern Asia", "SDG: Central Asia"])]

X = np.array(data_linear_reg["Youth_literacy"]).reshape(-1, 1)
y = list(data_linear_reg["Internet_Access"])

# Initialize linear regression object
linear_regressor = LinearRegression()

# Fit linear regression model of HDI on the log of CPI
linear_regressor.fit(np.log(X), y)

# Make predictions
# * Construct a sequence of values ranging from 10 to 95 and
#   apply logarithmic transform to them.
x_pred = np.log(np.linspace(8, 24, num=200).reshape(-1, 1))

# * Use .predict() method with the created sequence
y_pred = linear_regressor.predict(x_pred)  

# Plot regression line.
# * Logarithmic transformation is reverted by using the exponential one.
ax.plot(np.exp(x_pred), y_pred, color="#696969", lw=4, alpha=0.5)

#####################################################

#REGIONS = [i.split(": ")[1] for i in list(pd.unique(internet_literacy_data["Region"]))]
REGIONS = {}
for region, index in zip(internet_literacy_data["Region"], CATEGORY_CODES) :
    REGIONS[index] = region.split(": ")[1]

# Create handles for lines.
handles = [
    Line2D(
        [], [], label=label, 
        lw=0, # there's no line added, just the marker
        marker="o", # circle marker
        markersize=10, 
        markerfacecolor=REGION_COLS[idx], # marker fill color
    )
    for idx, label in zip(REGIONS.keys(), REGIONS.values())
]

#handles += [Line2D([], [], label="y ~ log(x) \n (Latin America and the Caribbean - \n Sub-Saharan Africa - Eastern, Central and South-Eastern Asia)", color="#696969", lw=2)]

legend = fig.legend(
    handles=handles,
    bbox_to_anchor=[0.5, -0.02], # Located in the top-mid of the figure.
    fontsize=12,
    handletextpad=0.6, # Space between text and marker/line
    handlelength=1.4, 
    columnspacing=1.4,
    loc="center", 
    ncol=4,
    frameon=False
)

#####################################################

TEXTS = []

data_label = internet_literacy_data[internet_literacy_data["Internet_Access"]<60]

for x, y, country in zip(data_label["Youth_literacy"], data_label["Internet_Access"], data_label["Country"]) :
    if country in ["Jordan", "Brazil"] :
        TEXTS.append(ax.text(x+0.2, y-3, country, fontsize=12))
    
#####################################################

ax.set_ylabel("Proficiency in reading at primary (% of students)", fontfamily="Tahoma", size=12)
ax.set_xlabel("Expenditure on education (% of total government expenditure)", fontfamily="Tahoma", size=12)
ax.set_title("Proficiency in reading at primary level in function of government expenditure \nin education", size=22, fontfamily="Tahoma", fontweight="bold", y=1.2)
ax.spines["left"].set_color("none")
ax.spines["right"].set_color("none")
ax.spines["top"].set_color("none")
ax.grid(axis="y")

fig.text(
    0, 0.96, "-Proficiency in reading at primary level (SGD 4, Indicator 4.1.1): Proportion of students at the end of primary education achieving \nat least a minimum proficiency level in reading (%).", 
    fontsize=16, fontfamily="Tahoma"
)
fig.text(
    0, 0.92, "-Government expenditure (SGD 4, Indicator 1.a.2): Expenditure on education as a percentage of total government expenditure (%).", 
    fontsize=16, fontfamily="Tahoma"
)
fig.text(
    0.035, -0.075, "__", 
    fontsize=16, fontweight="black", color="#696969"
)
fig.text(
    0.07, -0.085, "y ~ log(x) (Latin America and the Caribbean - Sub-Saharan Africa - Eastern, Central and South-Eastern Asia)", 
    fontsize=13, fontfamily="Tahoma"
)

plt.show()

# %% [markdown]
# # Last representation

# %%
electricity_primary = pd.read_csv("data/electricity.csv")

# %%
new_electricity_primary = pd.DataFrame()
for country in pd.unique(electricity_primary["Country"]) :
    last_year = max(list(electricity_primary[electricity_primary["Country"]==country]["Year"]))
    new_electricity_primary = pd.concat([new_electricity_primary, electricity_primary[(electricity_primary["Country"]==country)&(electricity_primary["Year"]==last_year)]])

# %%
new_electricity_primary
# Out:
#                                     Region                 Country Target  \
# 0           SDG: Central and Southern Asia             Afghanistan    4.a
# 2     SDG: Latin America and the Caribbean                Anguilla    4.a
# 5         SDG: Europe and Northern America                 Albania    4.a
# 11        SDG: Europe and Northern America                 Andorra    4.a
# 13   SDG: Northern Africa and Western Asia    United Arab Emirates    4.a
# ..                                     ...                     ...    ...
# 508   SDG: Latin America and the Caribbean  British Virgin Islands    4.a
# 514    SDG: Eastern and South-Eastern Asia                Viet Nam    4.a
# 519                           SDG: Oceania                   Samoa    4.a
# 521                SDG: Sub-Saharan Africa                  Zambia    4.a
# 524                SDG: Sub-Saharan Africa                Zimbabwe    4.a
#
#     Indicator Number                                     Indicator Name  Year  \
# ...

# %%
df_electricity_grouped = new_electricity_primary[["Region", "Value"]].groupby('Region').mean().reset_index().sort_values(by='Value', ascending=True)

# %%
df_electricity_grouped
# Out:
#                                   Region      Value
# 7                SDG: Sub-Saharan Africa  44.670938
# 1         SDG: Central and Southern Asia  80.115455
# 6                           SDG: Oceania  88.272143
# 2    SDG: Eastern and South-Eastern Asia  92.707500
# 4   SDG: Latin America and the Caribbean  94.530000
# 5  SDG: Northern Africa and Western Asia  99.022778
# 3       SDG: Europe and Northern America  99.708333
# 0                      SDG: Central Asia  99.890000

# %%
fig, ax = plt.subplots(figsize=(12, 7))
y = [i * 0.9 for i in range(len(df_electricity_grouped))]
ax.barh(y, df_electricity_grouped["Value"], height=0.55, align="edge", color="#076fa2")
ax.xaxis.set_ticks([i * 10 for i in range(0, 11)])
ax.xaxis.set_ticklabels([i * 10 for i in range(0, 11)], size=16, fontfamily="econsanscnd", fontweight=100)
ax.xaxis.set_tick_params(labelbottom=False, labeltop=True, length=0)

#########################################################
ax.set_xlim((0, 105))
ax.set_ylim((0, len(df_electricity_grouped) * 0.9 - 0.2))

ax.set_axisbelow(True)
ax.grid(axis = "x", color="#A8BAC4", lw=1.2)
ax.spines["right"].set_visible(False)
ax.spines["top"].set_visible(False)
ax.spines["bottom"].set_visible(False)
ax.spines["left"].set_lw(1.5)

ax.spines["left"].set_capstyle("butt")

ax.set_facecolor('none')

# Hide y labels
ax.yaxis.set_visible(False)

#########################################################

PAD = 0.3
for name, count, y_pos in zip(df_electricity_grouped["Region"], df_electricity_grouped["Value"], y):
    x = 0
    color = "white"
    path_effects = None
    if count < 40:
        x = count
        color = "#076fa2"   
        path_effects=[withStroke(linewidth=6, foreground="white")]
    
    ax.text(
        x + PAD, y_pos + 0.5 / 2, name.split(": ")[1], 
        color=color, fontfamily="Tahoma", fontsize=18, va="center",
        path_effects=path_effects
    )
    ax.text(
        count-10, y_pos + 0.5 / 2, "{}%".format(round(count,1)), 
        color=color, fontfamily="Tahoma", fontsize=18, va="center",
        path_effects=path_effects,
        fontweight="semibold"
    )
    

#########################################################

# Make room on top and bottom
# Note there's no room on the left and right sides
fig.subplots_adjust(left=0.005, right=1, top=0.8, bottom=0.1)

# Add title
fig.text(
    0, 0.925, "Proportion of primary schools with acces to electricity (%)", 
    fontsize=22, fontweight="bold", fontfamily="Tahoma"
)
# Add subtitle
fig.text(
    0, 0.875, "Regional average - (SGD 4, Indicator 4.a.1) - Last record available for each country between 2018 and 2023", 
    fontsize=16, fontfamily="Tahoma"
)

# Add caption
source = "Source: UIS Data (sdg4-data.uis.unesco.org)"
fig.text(
    0, 0.06, source, color="#a2a2a2", 
    fontsize=14, fontfamily="Tahoma"
)

# Add authorship
fig.text(
    0, 0.005, "Baptiste Gorteau - bgorteau.github.io", color="#a2a2a2",
    fontsize=16, fontfamily="Tahoma"
)

# Add line and rectangle on top.
fig.add_artist(lines.Line2D([0, 1], [1, 1], lw=3, color="#E3120B", solid_capstyle="butt"))
fig.add_artist(patches.Rectangle((0, 0.975), 0.05, 0.025, color="#E3120B"))

# Set facecolor, useful when saving as .png
fig.set_facecolor("white")

fig.savefig("figures/electricity_access.png", dpi=300, bbox_inches='tight', pad_inches=0.5)
